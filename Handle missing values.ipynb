# %%
import pandas as pd
df=pd.read_csv("newdata.csv")
df
# Out:
#    Unnamed: 0  Year LocationAbbr    LocationDesc DataSource  PriorityArea1  \
# 0           2  2001           GA         Georgia       NVSS            NaN
# 1           3  2001           NC  North Carolina       NVSS            NaN
# 2           4  2002           MT         Montana       NVSS            NaN
# 3           5  2003           OH            Ohio       NVSS            NaN
#
#    PriorityArea2  PriorityArea3  PriorityArea4                 Category  ...  \
# 0            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 1            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 2            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 3            NaN            NaN            NaN  Cardiovascular Diseases  ...
#
#   Break_Out_Category           Break_Out CategoryId TopicId  IndicatorID  \
# 0                Age                 75+         C1      T1        NV001
# ...

# %%
import pandas as pd
df=pd.read_csv("newdata.csv")[["Year","LocationAbbr","LocationDesc","BreakOutId","LocationID","GeoLocation"]]
df
# Out:
#    Year LocationAbbr    LocationDesc BreakOutId  LocationID  \
# 0  2001           GA         Georgia      AGE08          13
# 1  2001           NC  North Carolina      RAC02          37
# 2  2002           MT         Montana      GEN02          30
# 3  2003           OH            Ohio      RAC01          39
#
#                                 GeoLocation
# 0   (32.83968109300048, -83.62758034599966)
# 1  (35.466220975000454, -79.15925046299964)
# 2  (47.06652897200047, -109.42442064499971)
# 3   (40.06021014100048, -82.40426005599966)

# %%
df1=df[df.columns[:3]]
df1
# Out:
#   File "<ipython-input-22-ffbece773ec2>", line 2
#     df1.set_index['Year',inplace=True]
#                                 ^
# SyntaxError: invalid syntax

# %%
df1.set_index('Year',inplace=True)
df1
# Out:
#      LocationAbbr    LocationDesc
# Year
# 2001           GA         Georgia
# 2001           NC  North Carolina
# 2002           MT         Montana
# 2003           OH            Ohio

# %%
#writing two dataframes into different sheets of same excel file
stocks_df=pd.DataFrame(
{
    'type':['n.a','big','giant','mers'],
    'date':['1/2/2019','24/9/2019','n.a','8/8/2020'],
    'value':[10,20,30,'NULL']
})
medecine_df=pd.DataFrame(
{
    'name':['citrazen','paracetamol','digene'],
    'purpose':['headache','fever','stomach issues']
})

# %%
import pandas as pd

# %%
#continued
with pd.ExcelWriter('/Users/harshit_mac/Desktop/data science/new8.xlsx') as Writer:
    stocks_df.to_excel(Writer,sheet_name='stock_info',index=False)
    medecine_df.to_excel(Writer,sheet_name='medecine_info',index=False)

# %%
df2=pd.read_excel('/Users/harshit_mac/Desktop/data science/new8.xlsx')
df2
# Out:
#     type       date  value
# 0    n.a   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant        n.a   30.0
# 3   mers   8/8/2020    NaN

# %%
df2=pd.read_excel('/Users/harshit_mac/Desktop/data science/new8.xlsx',na_values={'n.a','n.a.','NULL'})
df2
# Out:
#     type       date  value
# 0    NaN   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant        NaN   30.0
# 3   mers   8/8/2020    NaN

# %%
df3=df2.fillna(
    {
        'type':'not known this type name',
        'date':'not known',
        'value':'x'}
)
df3
# Out:
#                        type       date value
# 0  not known this type name   1/2/2019    10
# 1                       big  24/9/2019    20
# 2                     giant  not known    30
# 3                      mers   8/8/2020     x

# %%
df2
# Out:
#     type       date  value
# 0    NaN   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant        NaN   30.0
# 3   mers   8/8/2020    NaN

# %%
#using forward fill method for the missing values to carry forward the previous value in place of missing ones 
df4=df2.fillna(method='ffill')
df4
# Out:
#     type       date  value
# 0    NaN   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant  24/9/2019   30.0
# 3   mers   8/8/2020   30.0

# %%
#using backward fill method for the missing values to carry backward the next value in place of missing ones 
df5=df2.fillna(method='bfill')
df5
# Out:
#     type       date  value
# 0    big   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant   8/8/2020   30.0
# 3   mers   8/8/2020    NaN

# %%
df2
# Out:
#     type       date  value
# 0    NaN   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant        NaN   30.0
# 3   mers   8/8/2020    NaN

# %%
#using forward fill method for missing values to carry forward the previous value in place of missing ones 
df6=df2.fillna(method='ffill',axis='columns')
df6
# Out:
#     type       date     value
# 0    NaN   1/2/2019        10
# 1    big  24/9/2019        20
# 2  giant      giant        30
# 3   mers   8/8/2020  8/8/2020

# %%
df2
# Out:
#     type       date  value
# 0    NaN   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant        NaN   30.0
# 3   mers   8/8/2020    NaN

# %%
#using forward fill method with limit for missing values to carry forward the previous value just to next missing value 
df7=df2.fillna(method='ffill',limit=1)
df4
# Out:
#     type       date  value
# 0    NaN   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant  24/9/2019   30.0
# 3   mers   8/8/2020   30.0

# %%
#make a better guess for missing values using linear interpolation
df8=df2.interpolate()
df8
# Out:
#     type       date  value
# 0    NaN   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant        NaN   30.0
# 3   mers   8/8/2020   30.0

# %%
#make a better guess for missing values using linear interpolation
df8=df2.interpolate(method='time')
df8
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-229c0302d636> in <module>
#       1 #make a better guess for missing values using linear interpolation
# ----> 2 df8=df2.interpolate(method='time')
#       3 df8
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7015             inplace=inplace,
#    7016             downcast=downcast,
# -> 7017             **kwargs,
#    7018         )
#    7019
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in interpolate(self, **kwargs)
#     568
#     569     def interpolate(self, **kwargs):
# --> 570         return self.apply("interpolate", **kwargs)
#     571
#     572     def shift(self, **kwargs):
#
# ...

# %%
df5
# Out:
#     type       date  value
# 0    big   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant   8/8/2020   30.0
# 3   mers   8/8/2020    NaN

# %%
#make a better guess for missing values using linear interpolation 
df8=df5.interpolate()
df8
# Out:
#     type       date  value
# 0    big   1/2/2019   10.0
# 1    big  24/9/2019   20.0
# 2  giant   8/8/2020   30.0
# 3   mers   8/8/2020   30.0

# %%
#make a better guess for missing values using linear interpolation
df8=df5.interpolate(method='time')
df8
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-e4ae895772fa> in <module>
#       1 #make a better guess for missing values using linear interpolation
# ----> 2 df8=df5.interpolate(method='time')
#       3 df8
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7015             inplace=inplace,
#    7016             downcast=downcast,
# -> 7017             **kwargs,
#    7018         )
#    7019
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in interpolate(self, **kwargs)
#     568
#     569     def interpolate(self, **kwargs):
# --> 570         return self.apply("interpolate", **kwargs)
#     571
#     572     def shift(self, **kwargs):
#
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-2ab97ebf9447> in <module>
#       1 #make a better guess for missing values using linear interpolation
# ----> 2 dff5=df5(parse_dates=['date'])
#       3 df8=dff5.interpolate(method='time')
#       4 df8
#
# TypeError: 'DataFrame' object is not callable

# %%
#writing two dataframes into different sheets of same excel file
stocks_df=pd.DataFrame(
{
    'type':['','big','giant','mers','n.a','n.a','cryo'],
    'date':['1/2/2019','24/9/2019','NULL','NULL','NULL','22/10/2019','8/8/2020'],
    'value':[10,'NULL',30,'NULL','n.a',99,28]
})
medecine_df=pd.DataFrame(
{
    'name':['citrazen','paracetamol','digene'],
    'purpose':['headache','fever','stomach issues']
})

# %%
#continued
with pd.ExcelWriter('/Users/harshit_mac/Desktop/data science/new10.xlsx') as Writer:
    stocks_df.to_excel(Writer,sheet_name='stock_info',index=False)
    medecine_df.to_excel(Writer,sheet_name='medecine_info',index=False)

# %%
dfc=pd.read_excel('/Users/harshit_mac/Desktop/data science/new10.xlsx',na_values={'n.a','','NULL'})
dfc
# Out:
#     type        date  value
# 0    NaN    1/2/2019   10.0
# 1    big   24/9/2019    NaN
# 2  giant         NaN   30.0
# 3   mers         NaN    NaN
# 4    NaN         NaN    NaN
# 5    NaN  22/10/2019   99.0
# 6   cryo    8/8/2020   28.0

# %%
dfc.dropna()
# Out:
#    type      date  value
# 6  cryo  8/8/2020   28.0

# %%
dfc['date']=pd.to_datetime(dfc['date'])
dfc
# Out:
#     type       date  value
# 0    NaN 2019-01-02   10.0
# 1    big 2019-09-24    NaN
# 2  giant        NaT   30.0
# 3   mers        NaT    NaN
# 4    NaN        NaT    NaN
# 5    NaN 2019-10-22   99.0
# 6   cryo 2020-08-08   28.0

# %%
dfd=dfc.dropna(subset=['date'])

# %%
dfd
# Out:
#    type       date  value
# 0   NaN 2019-01-02   10.0
# 1   big 2019-09-24    NaN
# 5   NaN 2019-10-22   99.0
# 6  cryo 2020-08-08   28.0

# %%
dfc
# Out:
#     type       date  value
# 0    NaN 2019-01-02   10.0
# 1    big 2019-09-24    NaN
# 2  giant        NaT   30.0
# 3   mers        NaT    NaN
# 4    NaN        NaT    NaN
# 5    NaN 2019-10-22   99.0
# 6   cryo 2020-08-08   28.0

# %%
#drops the rows that has all NaN values in columns
dfc.dropna(how='all')
# Out:
#     type       date  value
# 0    NaN 2019-01-02   10.0
# 1    big 2019-09-24    NaN
# 2  giant        NaT   30.0
# 3   mers        NaT    NaN
# 5    NaN 2019-10-22   99.0
# 6   cryo 2020-08-08   28.0

# %%
#keeps the rows that have atleast 2 non-NaN values 
dfc.dropna(thresh=2)
# Out:
#     type       date  value
# 0    NaN 2019-01-02   10.0
# 1    big 2019-09-24    NaN
# 2  giant        NaT   30.0
# 5    NaN 2019-10-22   99.0
# 6   cryo 2020-08-08   28.0

# %%
random1_df=pd.DataFrame(
{
    'date':['01/05/19','01/06/19','09/08/19','','17/12/19'],
    'type':['a',-999999,-999999,'a','b'],
    'name':['xy','yz','zx',-999999,''],
    'marks':[-999999,1,'',5,6]
})

# %%
random1_df.to_excel('/Users/harshit_mac/Desktop/data science/new11.xlsx')

# %%
random1_df
# Out:
#        date     type     name    marks
# 0  01/05/19        a       xy  -999999
# 1  01/06/19  -999999       yz        1
# 2  09/08/19  -999999       zx
# 3                  a  -999999        5
# 4  17/12/19        b                 6

# %%
random1_df['date']=pd.to_datetime(random1_df['date'])

# %%
random1_df
# Out:
#         date     type     name    marks
# 0 2019-01-05        a       xy  -999999
# 1 2019-01-06  -999999       yz        1
# 2 2019-09-08  -999999       zx
# 3        NaT        a  -999999        5
# 4 2019-12-17        b                 6

# %%
dx=pd.read_excel('/Users/harshit_mac/Desktop/data science/new11.xlsx',na_values={'','n.a'},index=False)
dx=dx[dx.columns[1:]]
dx
# Out:
#        date     type     name     marks
# 0  01/05/19        a       xy -999999.0
# 1  01/06/19  -999999       yz       1.0
# 2  09/08/19  -999999       zx       NaN
# 3       NaN        a  -999999       5.0
# 4  17/12/19        b      NaN       6.0

# %%
dx['date']=pd.to_datetime(dx['date'])

# %%
dx
# Out:
#         date     type     name     marks
# 0 2019-01-05        a       xy -999999.0
# 1 2019-01-06  -999999       yz       1.0
# 2 2019-09-08  -999999       zx       NaN
# 3        NaT        a  -999999       5.0
# 4 2019-12-17        b      NaN       6.0

# %%
dxn=dx.replace(-999999,
              {
                  'type':'not known',
                  'name':'who knows!',
                  'marks':1
              })

# %%
dxn
# Out:
#         date       type        name  marks
# 0 2019-01-05          a          xy    1.0
# 1 2019-01-06  not known          yz    1.0
# 2 2019-09-08  not known          zx    NaN
# 3        NaT          a  who knows!    5.0
# 4 2019-12-17          b         NaN    6.0

# %%
import numpy as np
dxm=dx.replace(-999999,np.NaN)

# %%
dxm
# Out:
#         date type name  marks
# 0 2019-01-05    a   xy    NaN
# 1 2019-01-06  NaN   yz    1.0
# 2 2019-09-08  NaN   zx    NaN
# 3        NaT    a  NaN    5.0
# 4 2019-12-17    b  NaN    6.0

# %%
dxn.interpolate()
# Out:
#         date       type        name  marks
# 0 2019-01-05          a          xy    1.0
# 1 2019-01-06  not known          yz    1.0
# 2 2019-09-08  not known          zx    3.0
# 3        NaT          a  who knows!    5.0
# 4 2019-12-17          b         NaN    6.0

# %%
dxn.fillna(method='ffill')
# Out:
#         date       type        name  marks
# 0 2019-01-05          a          xy    1.0
# 1 2019-01-06  not known          yz    1.0
# 2 2019-09-08  not known          zx    1.0
# 3 2019-09-08          a  who knows!    5.0
# 4 2019-12-17          b  who knows!    6.0

# %%
random1_df=pd.DataFrame(
{
    'date':['01/05/19','01/06/19','09/08/19','','17/12/19'],
    'temp':['50','45 F','29','65 f','']
})

# %%
random1_df.to_excel('/Users/harshit_mac/Desktop/data science/new12.xlsx')

# %%
dfq=pd.read_excel('/Users/harshit_mac/Desktop/data science/new12.xlsx')
dfq=dfq[dfq.columns[1:]]
dfq
# Out:
#        date  temp
# 0  01/05/19    50
# 1  01/06/19  45 F
# 2  09/08/19    29
# 3       NaN  65 f
# 4  17/12/19   NaN

# %%
dfq.set_index('date',inplace=True)

# %%
dfq
# Out:
#           temp
# date
# 01/05/19    50
# 01/06/19  45 F
# 09/08/19    29
# NaN       65 f
# 17/12/19   NaN

# %%
dfq1=dfq.interpolate()
dfq1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-cae5be01e9e3> in <module>
# ----> 1 dfq1=dfq.interpolate()
#       2 dfq1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6973         ):
#    6974             raise TypeError(
# -> 6975                 "Cannot interpolate with all object-dtype columns "
#    6976                 "in the DataFrame. Try setting at least one "
#    6977                 "column to a numeric dtype."
#
# TypeError: Cannot interpolate with all object-dtype columns in the DataFrame. Try setting at least one column to a numeric dtype.

# %%
dfq1=pd.read_excel('/Users/harshit_mac/Desktop/data science/new12.xlsx')
dfq1=dfq1[dfq1.columns[1:]]
dfq1
# Out:
#        date  temp
# 0  01/05/19    50
# 1  01/06/19  45 F
# 2  09/08/19    29
# 3       NaN  65 f
# 4  17/12/19   NaN

# %%
dfq1=dfq1.fillna(method='ffill')
dfq1
# Out:
#        date  temp
# 0  01/05/19    50
# 1  01/06/19  45 F
# 2  09/08/19    29
# 3  09/08/19  65 f
# 4  17/12/19  65 f

# %%
dfq2=dfq1.replace({'temp':'[A-Za-z]'},'',regex=True)
dfq2
# Out:
#        date temp
# 0  01/05/19   50
# 1  01/06/19  45
# 2  09/08/19   29
# 3  09/08/19  65
# 4  17/12/19  65

# %%
type(dfq2.temp)
# Out:
# pandas.core.series.Series

# %%
dfq2['temp'].to_numeric(dfq2['temp'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-202-665100884728> in <module>
# ----> 1 dfq2['temp'].to_numeric(dfq2['temp'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_numeric'

# %%
dfq2['temp']=dfq2['temp'].astype(int)

# %%
type(dfq2['temp'])
# Out:
# pandas.core.series.Series

# %%
dfq2.dtypes
# Out:
# date    object
# temp     int64
# dtype: object

# %%
dfq2
# Out:
#        date  temp
# 0  01/05/19    50
# 1  01/06/19    45
# 2  09/08/19    29
# 3  09/08/19    65
# 4  17/12/19    65

# %%
#how can we replace a list with another list in the dataframe                             *very important*
dfq3=dfq2.replace([65,29,45],['very high','very low','very good'])
dfq3
# Out:
#        date       temp
# 0  01/05/19         50
# 1  01/06/19  very good
# 2  09/08/19   very low
# 3  09/08/19  very high
# 4  17/12/19  very high

# %%
#to check if there is any na values in the columns
df.columns[df.isna().any()]                                                      #important
