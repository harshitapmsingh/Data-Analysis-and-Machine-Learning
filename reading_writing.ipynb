# %%
import pandas as pd
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv")
df
# Out:
#    My_header    Unnamed: 1      Unnamed: 2  Unnamed: 3     Unnamed: 4  \
# 0       Year  LocationAbbr    LocationDesc  DataSource  PriorityArea1
# 1       2000            IN         Indiana        NVSS           None
# 2       2000            US   United States        NVSS           None
# 3       2001            GA         Georgia        NVSS           None
# 4       2001            NC  North Carolina        NVSS           None
# 5       2002            MT         Montana        NVSS           None
# 6       2003            OH            Ohio        NVSS           None
# 7       2004            AZ         Arizona        NVSS           None
# 8       2004            ME           Maine        NVSS             na
# 9       2004            TX           Texas        NVSS           None
# 10      2004            UT            Utah        NVSS           None
#
#        Unnamed: 5     Unnamed: 6     Unnamed: 7               Unnamed: 8  \
# ...

# %%
import pandas as pd
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",skiprows=1)
df
# Out:
#    Year LocationAbbr    LocationDesc DataSource PriorityArea1 PriorityArea2  \
# 0  2000           IN         Indiana       NVSS          None          None
# 1  2000           US   United States       NVSS          None          None
# 2  2001           GA         Georgia       NVSS          None          None
# 3  2001           NC  North Carolina       NVSS          None           NaN
# 4  2002           MT         Montana       NVSS          None          None
# 5  2003           OH            Ohio       NVSS          None          None
# 6  2004           AZ         Arizona       NVSS          None          None
# 7  2004           ME           Maine       NVSS            na          None
# 8  2004           TX           Texas       NVSS          None          None
# 9  2004           UT            Utah       NVSS          None          None
#
#    PriorityArea3 PriorityArea4                 Category  \
# 0           None          None  Cardiovascular Diseases
# ...

# %%
df[4:7]
# Out:
#    Year LocationAbbr LocationDesc DataSource PriorityArea1 PriorityArea2  \
# 4  2002           MT      Montana       NVSS          None          None
# 5  2003           OH         Ohio       NVSS          None          None
# 6  2004           AZ      Arizona       NVSS          None          None
#
#    PriorityArea3 PriorityArea4                 Category  \
# 4           None          None  Cardiovascular Diseases
# 5           None          None  Cardiovascular Diseases
# 6  Not Available          None  Cardiovascular Diseases
#
#                           Topic  ... Break_Out_Category           Break_Out  \
# 4  Major Cardiovascular Disease  ...             Gender              Female
# 5  Major Cardiovascular Disease  ...               Race  Non-Hispanic White
# 6  Major Cardiovascular Disease  ...                Age                 35+
#
#   CategoryId  TopicId  IndicatorID  Data_Value_TypeID  BreakOutCategoryId  \
# ...

# %%
df[:4]
# Out:
#    Year LocationAbbr    LocationDesc DataSource PriorityArea1 PriorityArea2  \
# 0  2000           IN         Indiana       NVSS          None          None
# 1  2000           US   United States       NVSS          None          None
# 2  2001           GA         Georgia       NVSS          None          None
# 3  2001           NC  North Carolina       NVSS          None           NaN
#
#   PriorityArea3 PriorityArea4                 Category  \
# 0          None          None  Cardiovascular Diseases
# 1          None          None  Cardiovascular Diseases
# 2          None          None  Cardiovascular Diseases
# 3          None          None  Cardiovascular Diseases
#
#                           Topic  ... Break_Out_Category           Break_Out  \
# 0  Major Cardiovascular Disease  ...                Age               45-64
# 1  Major Cardiovascular Disease  ...                Age                 35+
# 2  Major Cardiovascular Disease  ...                Age                 75+
# ...

# %%
import pandas as pd
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv")
df
# Out:
#    My_header    Unnamed: 1      Unnamed: 2  Unnamed: 3     Unnamed: 4  \
# 0       Year  LocationAbbr    LocationDesc  DataSource  PriorityArea1
# 1       2000            IN         Indiana        NVSS           None
# 2       2000            US   United States        NVSS           None
# 3       2001            GA         Georgia        NVSS           None
# 4       2001            NC  North Carolina        NVSS           None
# 5       2002            MT         Montana        NVSS           None
# 6       2003            OH            Ohio        NVSS           None
# 7       2004            AZ         Arizona        NVSS           None
# 8       2004            ME           Maine        NVSS             na
# 9       2004            TX           Texas        NVSS           None
# 10      2004            UT            Utah        NVSS           None
#
#        Unnamed: 5     Unnamed: 6     Unnamed: 7               Unnamed: 8  \
# ...

# %%
import pandas as pd
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",header=None)
df
# Out:
#            0             1               2           3              4   \
# 0   My_header           NaN             NaN         NaN            NaN
# 1        Year  LocationAbbr    LocationDesc  DataSource  PriorityArea1
# 2        2000            IN         Indiana        NVSS           None
# 3        2000            US   United States        NVSS           None
# 4        2001            GA         Georgia        NVSS           None
# 5        2001            NC  North Carolina        NVSS           None
# 6        2002            MT         Montana        NVSS           None
# 7        2003            OH            Ohio        NVSS           None
# 8        2004            AZ         Arizona        NVSS           None
# 9        2004            ME           Maine        NVSS             na
# 10       2004            TX           Texas        NVSS           None
# 11       2004            UT            Utah        NVSS           None
#
# ...

# %%
import pandas as pd
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",header=1)
df
# Out:
#    Year LocationAbbr    LocationDesc DataSource PriorityArea1 PriorityArea2  \
# 0  2000           IN         Indiana       NVSS          None          None
# 1  2000           US   United States       NVSS          None          None
# 2  2001           GA         Georgia       NVSS          None          None
# 3  2001           NC  North Carolina       NVSS          None           NaN
# 4  2002           MT         Montana       NVSS          None          None
# 5  2003           OH            Ohio       NVSS          None          None
# 6  2004           AZ         Arizona       NVSS          None          None
# 7  2004           ME           Maine       NVSS            na          None
# 8  2004           TX           Texas       NVSS          None          None
# 9  2004           UT            Utah       NVSS          None          None
#
#    PriorityArea3 PriorityArea4                 Category  \
# 0           None          None  Cardiovascular Diseases
# ...

# %%
#when we have missing cloumn names,use
#df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",names={'ab','bc','cd'....})

# %%
#nrows reads first n rows excluding the header
import pandas as pd
df2=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",nrows=7)
df2
# Out:
#   My_header    Unnamed: 1      Unnamed: 2  Unnamed: 3     Unnamed: 4  \
# 0      Year  LocationAbbr    LocationDesc  DataSource  PriorityArea1
# 1      2000            IN         Indiana        NVSS           None
# 2      2000            US   United States        NVSS           None
# 3      2001            GA         Georgia        NVSS           None
# 4      2001            NC  North Carolina        NVSS           None
# 5      2002            MT         Montana        NVSS           None
# 6      2003            OH            Ohio        NVSS           None
#
#       Unnamed: 5     Unnamed: 6     Unnamed: 7               Unnamed: 8  \
# 0  PriorityArea2  PriorityArea3  PriorityArea4                 Category
# 1           None           None           None  Cardiovascular Diseases
# 2           None           None           None  Cardiovascular Diseases
# 3           None           None           None  Cardiovascular Diseases
# ...

# %%
df
# Out:
#    Year LocationAbbr    LocationDesc DataSource PriorityArea1 PriorityArea2  \
# 0  2000           IN         Indiana       NVSS          None          None
# 1  2000           US   United States       NVSS          None          None
# 2  2001           GA         Georgia       NVSS          None          None
# 3  2001           NC  North Carolina       NVSS          None           NaN
# 4  2002           MT         Montana       NVSS          None          None
# 5  2003           OH            Ohio       NVSS          None          None
# 6  2004           AZ         Arizona       NVSS          None          None
# 7  2004           ME           Maine       NVSS            na          None
# 8  2004           TX           Texas       NVSS          None          None
# 9  2004           UT            Utah       NVSS          None          None
#
#    PriorityArea3 PriorityArea4                 Category  \
# 0           None          None  Cardiovascular Diseases
# ...

# %%
import pandas as pd
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",na_values={'None','na','Not Available'})
df
#to make some values to NaN only for particular columns,use a dictionary to specify column names with the values 
#to convert to NaN
# Out:
#    My_header    Unnamed: 1      Unnamed: 2  Unnamed: 3     Unnamed: 4  \
# 0       Year  LocationAbbr    LocationDesc  DataSource  PriorityArea1
# 1       2000            IN         Indiana        NVSS            NaN
# 2       2000            US   United States        NVSS            NaN
# 3       2001            GA         Georgia        NVSS            NaN
# 4       2001            NC  North Carolina        NVSS            NaN
# 5       2002            MT         Montana        NVSS            NaN
# 6       2003            OH            Ohio        NVSS            NaN
# 7       2004            AZ         Arizona        NVSS            NaN
# 8       2004            ME           Maine        NVSS            NaN
# 9       2004            TX           Texas        NVSS            NaN
# 10      2004            UT            Utah        NVSS            NaN
#
#        Unnamed: 5     Unnamed: 6     Unnamed: 7               Unnamed: 8  \
# ...

# %%
import pandas as pd
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",header=1,na_values={'None','na','Not Available'})
df
# Out:
#    Year LocationAbbr    LocationDesc DataSource  PriorityArea1  PriorityArea2  \
# 0  2000           IN         Indiana       NVSS            NaN            NaN
# 1  2000           US   United States       NVSS            NaN            NaN
# 2  2001           GA         Georgia       NVSS            NaN            NaN
# 3  2001           NC  North Carolina       NVSS            NaN            NaN
# 4  2002           MT         Montana       NVSS            NaN            NaN
# 5  2003           OH            Ohio       NVSS            NaN            NaN
# 6  2004           AZ         Arizona       NVSS            NaN            NaN
# 7  2004           ME           Maine       NVSS            NaN            NaN
# 8  2004           TX           Texas       NVSS            NaN            NaN
# 9  2004           UT            Utah       NVSS            NaN            NaN
#
#    PriorityArea3  PriorityArea4                 Category  \
# ...

# %%
#creates a new csv file in mentioned directory with data of df requested,
#index=false removes the serial numbers of rows copied from df,try difference
df[2:6].to_csv("/Users/harshit_mac/Desktop/data science/newdata.csv",index=False)

# %%
#to skip writing the header to new file
df[2:6].to_csv("/Users/harshit_mac/Desktop/data science/newdata.csv",header=False)

# %%
import pandas as pd
df=pd.read_excel("/Users/harshit_mac/Desktop/data science/newdata.xlsx",header=1,na_values={'None','na','Not Available'})
df
# Out:
#    2  2001  GA         Georgia  NVSS  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0  3  2001  NC  North Carolina  NVSS         NaN         NaN         NaN
# 1  4  2002  MT         Montana  NVSS         NaN         NaN         NaN
# 2  5  2003  OH            Ohio  NVSS         NaN         NaN         NaN
#
#    Unnamed: 8  Cardiovascular Diseases  ...     Age                  75  C1  \
# 0         NaN  Cardiovascular Diseases  ...    Race  Non-Hispanic Black  C1
# 1         NaN  Cardiovascular Diseases  ...  Gender              Female  C1
# 2         NaN  Cardiovascular Diseases  ...    Race  Non-Hispanic White  C1
#
#    T1  NV001  Crude.1  BOC03  AGE08  13  \
# 0  T1  NV001    Crude  BOC04  RAC02  37
# 1  T1  NV001    Crude  BOC02  GEN02  30
# 2  T1  NV001    Crude  BOC04  RAC01  39
#
#     (32.83968109300048, -83.62758034599966)
# 0  (35.466220975000454, -79.15925046299964)
# 1  (47.06652897200047, -109.42442064499971)
# 2   (40.06021014100048, -82.40426005599966)
#
# ...

# %%
#use of converters in changing the values
import pandas as pd 
df=pd.read_csv("/Users/harshit_mac/Desktop/data science/data_exp.csv",na_values={'None','na','Not Available'})
df
# Out:
#    My_header    Unnamed: 1      Unnamed: 2  Unnamed: 3     Unnamed: 4  \
# 0       Year  LocationAbbr    LocationDesc  DataSource  PriorityArea1
# 1       2000            IN         Indiana        NVSS            NaN
# 2       2000            US   United States        NVSS            NaN
# 3       2001            GA         Georgia        NVSS            NaN
# 4       2001            NC  North Carolina        NVSS            NaN
# 5       2002            MT         Montana        NVSS            NaN
# 6       2003            OH            Ohio        NVSS            NaN
# 7       2004            AZ         Arizona        NVSS            NaN
# 8       2004            ME           Maine        NVSS            NaN
# 9       2004            TX           Texas        NVSS            NaN
# 10      2004            UT            Utah        NVSS            NaN
#
#        Unnamed: 5     Unnamed: 6     Unnamed: 7               Unnamed: 8  \
# ...

# %%
df[0:6].to_csv("/Users/harshit_mac/Desktop/data science/newdata1.csv",header=False)

# %%
import pandas as pd
df=pd.read_excel("/Users/harshit_mac/Desktop/data science/newdata1excel.xlsx",header=1,na_values={'None','na','Not Available'})
df
# Out:
#    0  Year LocationAbbr    LocationDesc DataSource  PriorityArea1  \
# 0  1  2000           IN         Indiana       NVSS            NaN
# 1  2  2000           US   United States       NVSS            NaN
# 2  3  2001           GA         Georgia       NVSS            NaN
# 3  4  2001           NC  North Carolina       NVSS            NaN
# 4  5  2002           MT         Montana       NVSS            NaN
#
#    PriorityArea2  PriorityArea3  PriorityArea4                 Category  ...  \
# 0            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 1            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 2            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 3            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 4            NaN            NaN            NaN  Cardiovascular Diseases  ...
#
#   Break_Out_Category           Break_Out CategoryId TopicId  IndicatorID  \
# ...

# %%
df.to_excel("/Users/harshit_mac/Desktop/data science/newdata1excelnew.xlsx")

# %%
#using converters to convert messy data into something useful

# %%
#this writes back the dataframe into a new csv file
df.to_csv("/Users/harshit_mac/Desktop/data science/newdata5.csv")

# %%
df[df.columns[1:6]]
# Out:
#    Year LocationAbbr    LocationDesc DataSource  PriorityArea1
# 0  2000           IN         Indiana       NVSS            NaN
# 1  2000           US   United States       NVSS            NaN
# 2  2001           GA         Georgia       NVSS            NaN
# 3  2001           NC  North Carolina       NVSS            NaN
# 4  2002           MT         Montana       NVSS            NaN

# %%
df
# Out:
#    0  Year LocationAbbr    LocationDesc DataSource  PriorityArea1  \
# 0  1  2000           IN         Indiana       NVSS            NaN
# 1  2  2000           US   United States       NVSS            NaN
# 2  3  2001           GA         Georgia       NVSS            NaN
# 3  4  2001           NC  North Carolina       NVSS            NaN
# 4  5  2002           MT         Montana       NVSS            NaN
#
#    PriorityArea2  PriorityArea3  PriorityArea4                 Category  ...  \
# 0            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 1            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 2            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 3            NaN            NaN            NaN  Cardiovascular Diseases  ...
# 4            NaN            NaN            NaN  Cardiovascular Diseases  ...
#
#   Break_Out_Category           Break_Out CategoryId TopicId  IndicatorID  \
# ...

# %%
df=df[df.columns[1:9]]

# %%
df
# Out:
#    Year LocationAbbr    LocationDesc DataSource  PriorityArea1  PriorityArea2  \
# 0  2000           IN         Indiana       NVSS            NaN            NaN
# 1  2000           US   United States       NVSS            NaN            NaN
# 2  2001           GA         Georgia       NVSS            NaN            NaN
# 3  2001           NC  North Carolina       NVSS            NaN            NaN
# 4  2002           MT         Montana       NVSS            NaN            NaN
#
#    PriorityArea3  PriorityArea4
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN

# %%
df=df[df.columns.difference(['DataSource','PriorityArea2','PriorityArea4'])]

# %%
df
# Out:
#   LocationAbbr    LocationDesc  PriorityArea1  PriorityArea3  Year
# 0           IN         Indiana            NaN            NaN  2000
# 1           US   United States            NaN            NaN  2000
# 2           GA         Georgia            NaN            NaN  2001
# 3           NC  North Carolina            NaN            NaN  2001
# 4           MT         Montana            NaN            NaN  2002

# %%
#for writing at certain offset in the excel or csv file
#see this screenshot-------/Users/harshit_mac/Desktop/Screenshot 2020-05-18 at 03.06.14.png
df.to_excel("/Users/harshit_mac/Desktop/data science/new6.xlsx",sheet_name="xyz",startrow=3,startcol=5,index=False)

# %%
#writing two dataframes into different sheets of same excel file
stocks_df=pd.DataFrame(
{
    'type':['smes','big','giant'],
    'date':['1/2/2019','24/9/2019','19/4/2020'],
    'value':[10,20,30]
})
medecine_df=pd.DataFrame(
{
    'name':['citrazen','paracetamol','digene'],
    'purpose':['headache','fever','stomach issues']
})

# %%
#continued
with pd.ExcelWriter('/Users/harshit_mac/Desktop/data science/new7.xlsx') as Writer:
    stocks_df.to_excel(Writer,sheet_name='stock_info',index=False)
    medecine_df.to_excel(Writer,sheet_name='medecine_info',index=False)

# %%
df=pd.read_excel('/Users/harshit_mac/Desktop/data science/new7.xlsx')
df
# Out:
#     type       date  value
# 0   smes   1/2/2019     10
# 1    big  24/9/2019     20
# 2  giant  19/4/2020     30

# %%
df1=pd.read_excel('/Users/harshit_mac/Desktop/data science/new7.xlsx',sheet_name='medecine_info',index=False)
df1
# Out:
#           name         purpose
# 0     citrazen        headache
# 1  paracetamol           fever
# 2       digene  stomach issues
