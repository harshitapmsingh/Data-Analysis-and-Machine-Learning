# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import math

# %%
df=pd.read_csv("/Users/harshit_mac/Desktop/datascience/homeprices.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
#analyse the values variations,to judge for the na values

# %%
median_bedrooms=math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 4

# %%
df.bedrooms=df.bedrooms.fillna(median_bedrooms)

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[3950,3,4]])
# Out:
# array([721209.41613612])

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# 221323.00186540408

# %%
112.06244194*3950+23388.88007794*3-3231.71790863*4+221323.00186540408
# Out:
# 721209.4161277041

# %%
reg.predict([[4000,5,7]])
# Out:
# array([763895.14466321])

# %%
df1=pd.read_csv("/Users/harshit_mac/Desktop/datascience/hiring.csv")
df1
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df1=df1.fillna(
           {'experience':'zero'}
)
df1
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df1=df1.interpolate()
df1
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    7.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
from word2number import w2n

# %%
df1.experience=df1.experience.apply(w2n.word_to_num)

# %%
df1
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg=linear_model.LinearRegression()
reg.fit(df1[['experience','test_score(out of 10)','interview_score(out of 10)']],df1['salary($)'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[10,10,10]])
# Out:
# array([87903.25825647])

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import math

# %%
def gradient_descent(x1,x2,x3,y):
    m1_curr = 0
    m2_curr = 0
    m3_curr = 0
    b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.0002

    cost_previous = 0

    for i in range(iterations):
        y_predicted = m1_curr * x1 + m2_curr * x2 + m3_curr * x3 + b_curr
        cost = (1/n)*sum([value**2 for value in (y-y_predicted)])
        m1d = -(2/n)*sum(x1*(y-y_predicted))
        m2d = -(2/n)*sum(x2*(y-y_predicted))
        m3d = -(2/n)*sum(x3*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m1_curr = m1_curr - learning_rate * m1d
        m2_curr = m2_curr - learning_rate * m2d
        m3_curr = m3_curr - learning_rate * m3d
        b_curr = b_curr - learning_rate * bd
        if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
        cost_previous = cost
        print ("m1 {}, m2 {}, m3 {}, b {}, cost {}, iteration {}".format(m1_curr,m2_curr,m3_curr,b_curr,cost, i))

    return m1_curr,m2_curr,m3_curr, b_curr

# %%
df = pd.read_csv("/Users/harshit_mac/Desktop/datascience/hiring.csv")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
x1 = np.array(df1.experience)
x2 = np.array(df1['test_score(out of 10)'])
x3 = np.array(df1['interview_score(out of 10)'])
y = np.array(df1['salary($)'])

m1,m2,m3,b = gradient_descent(x1,x2,x3,y)
print("Using gradient descent function: Coef1 {} Coef2 {} Coef3 {} Intercept {}".format(m1,m2,m3,b))
# Out:
# m1 108.24000000000001, m2 155.92000000000002, m3 158.96, b 20.16, cost 3267800000.0, iteration 0
# m1 211.5511552, m2 304.3829056000001, m3 310.29841600000003, b 39.3617632, cost 2966609377.416321, iteration 1
# m1 310.16634928652803, m2 445.7429369703681, m3 454.377313551872, b 57.650788065664, cost 2693316684.2443447, iteration 2
# m1 404.3074186794199, m2 580.337501812249, m3 591.5415732428136, b 75.07041364873024, cost 2445336866.376079, iteration 3
# m1 494.18567679720564, m2 708.4879932662895, m3 722.1197062830788, b 91.66192207090366, cost 2220324413.615566, iteration 4
# m1 580.0024134415761, m2 830.5005499534728, m3 846.4246313867907, b 107.46463614397547, cost 2016151162.2566452, iteration 5
# m1 661.9493704817506, m2 946.6667799452316, m3 964.7544147828198, b 122.51601235699887, cost 1830886154.5937467, iteration 6
# m1 740.2091949635243, m2 1057.2644503747147, m3 1077.3929751055377, b 136.85172945039548, cost 1662777364.7591786, iteration 7
# ...
